# %%
from keras.models import Sequential
from keras.layers import Dense 
from keras.optimizers import Adam, SGD

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import io

from google.colab import files
# Out:
# Using TensorFlow backend.

# %%
uploaded =  files.upload()
# Out:
#      <input type="file" id="files-8bf45308-56b6-4d40-871a-931395bd1f73" name="files[]" multiple disabled />
#      <output id="result-8bf45308-56b6-4d40-871a-931395bd1f73">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving weight-height.csv to weight-height.csv

# %%
df=pd.read_csv(io.StringIO(uploaded['weight-height.csv'].decode('utf-8')))

# %%
X=df[['Height']].values
y_true=df[['Weight']].values

# %%
X
# Out:
# array([[73.84701702],
#        [68.78190405],
#        [74.11010539],
#        ...,
#        [63.86799221],
#        [69.03424313],
#        [61.94424588]])

# %%
model = Sequential()
model.add(Dense(1, input_shape=(1,)))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(Adam(lr=0.8), 'mean_squared_error')

# %%
model.fit(X,y_true, epochs=40)
# Out:
# Epoch 1/40
# 10000/10000 [==============================] - 2s 212us/step - loss: 1579.4492
# Epoch 2/40
# 10000/10000 [==============================] - 1s 133us/step - loss: 564.0015
# Epoch 3/40
# 10000/10000 [==============================] - 1s 136us/step - loss: 526.5400
# Epoch 4/40
# 10000/10000 [==============================] - 1s 133us/step - loss: 501.8032
# Epoch 5/40
# 10000/10000 [==============================] - 1s 131us/step - loss: 464.2540
# Epoch 6/40
# 10000/10000 [==============================] - 1s 134us/step - loss: 422.2432
# Epoch 7/40
# 10000/10000 [==============================] - 1s 134us/step - loss: 383.2114
# Epoch 8/40
# 10000/10000 [==============================] - 1s 131us/step - loss: 354.0125
# Epoch 9/40
#  7072/10000 [====================>.........] - ETA: 0s - loss: 319.1828
# 10000/10000 [==============================] - 1s 136us/step - loss: 330.7565
# Epoch 10/40
# 10000/10000 [==============================] - 1s 131us/step - loss: 308.1549
# Epoch 11/40
# 10000/10000 [==============================] - 1s 132us/step - loss: 265.4723
# Epoch 12/40
# 10000/10000 [==============================] - 1s 132us/step - loss: 251.2816
# Epoch 13/40
# 10000/10000 [==============================] - 1s 134us/step - loss: 236.2687
# Epoch 14/40
# 10000/10000 [==============================] - 1s 131us/step - loss: 233.7811
# Epoch 15/40
# 10000/10000 [==============================] - 1s 133us/step - loss: 219.0363
# Epoch 16/40
# 10000/10000 [==============================] - 1s 132us/step - loss: 192.1217
# Epoch 17/40
#  8832/10000 [=========================>....] - ETA: 0s - loss: 200.4305
# 10000/10000 [==============================] - 1s 131us/step - loss: 200.0826
# Epoch 18/40
# 10000/10000 [==============================] - 1s 132us/step - loss: 194.9481
# Epoch 19/40
# 10000/10000 [==============================] - 1s 133us/step - loss: 192.4193
# Epoch 20/40
# 10000/10000 [==============================] - 1s 133us/step - loss: 194.3338
# Epoch 21/40
# 10000/10000 [==============================] - 1s 132us/step - loss: 196.3261
# Epoch 22/40
# 10000/10000 [==============================] - 1s 131us/step - loss: 173.5869
# Epoch 23/40
# 10000/10000 [==============================] - 1s 134us/step - loss: 183.1789
# Epoch 24/40
# 10000/10000 [==============================] - 1s 134us/step - loss: 180.9930
# Epoch 25/40
#  8288/10000 [=======================>......] - ETA: 0s - loss: 187.0451
# 10000/10000 [==============================] - 1s 133us/step - loss: 184.5275
# Epoch 26/40
# 10000/10000 [==============================] - 1s 129us/step - loss: 179.7137
# Epoch 27/40
# 10000/10000 [==============================] - 1s 132us/step - loss: 174.2427
# Epoch 28/40
# 10000/10000 [==============================] - 1s 132us/step - loss: 175.0355
# Epoch 29/40
# 10000/10000 [==============================] - 1s 129us/step - loss: 179.7483
# Epoch 30/40
# 10000/10000 [==============================] - 1s 131us/step - loss: 168.2100
# Epoch 31/40
# 10000/10000 [==============================] - 1s 131us/step - loss: 182.9216
# Epoch 32/40
# 10000/10000 [==============================] - 1s 133us/step - loss: 186.7959
# Epoch 33/40
#  8960/10000 [=========================>....] - ETA: 0s - loss: 181.2564
# 10000/10000 [==============================] - 1s 135us/step - loss: 178.5180
# Epoch 34/40
# 10000/10000 [==============================] - 1s 135us/step - loss: 178.7970
# Epoch 35/40
# 10000/10000 [==============================] - 1s 131us/step - loss: 185.2456
# Epoch 36/40
# 10000/10000 [==============================] - 1s 130us/step - loss: 172.0951
# Epoch 37/40
# 10000/10000 [==============================] - 1s 135us/step - loss: 187.3867
# Epoch 38/40
# 10000/10000 [==============================] - 1s 133us/step - loss: 180.3226
# Epoch 39/40
# 10000/10000 [==============================] - 1s 131us/step - loss: 181.4120
# Epoch 40/40
# 10000/10000 [==============================] - 1s 132us/step - loss: 190.5891

# %%
y_pred=model.predict(X)

# %%
df.plot(kind='scatter',
       x='Height',
       y='Weight', title='Weight and Height in adults')
plt.plot(X, y_pred, color='red', linewidth=3)

# %%
w,b=model.get_weights()

# %%
w
# Out:
# array([[7.7116947]], dtype=float32)

# %%
b
# Out:
# array([-347.6568], dtype=float32)
